# %%
# !pip install ipynb

# %%
from ipynb.fs.full.FLDataset import load_dataset, getActualImages

# %%
# 10 is the number of MNIST classes (0 to 9)
train_dataset, test_dataset, train_group, test_group = load_dataset(10)

# %%
# 60.000 images
train_dataset
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.1307,), std=(0.3081,))
#            )

# %%
# dict client -> 6k images, where there are 10 clients (0 to 9)
train_group
# Out:
# {0: {17,
#   18,
#   32789,
#   32793,
#   28,
#   32801,
#   32803,
#   32816,
#   50,
#   32822,
#   66,
#   32837,
#   72,
#   32841,
#   32855,
#   89,
#   32863,
#   32866,
#   101,
#   32880,
#   32892,
#   32893,
#   125,
#   32898,
#   32899,
#   134,
#   32905,
#   32906,
#   32917,
#   151,
#   32922,
#   154,
#   32923,
#   157,
#   32924,
#   159,
#   32931,
#   32940,
#   181,
#   32955,
#   190,
#   194,
#   32965,
#   200,
#   204,
#   32976,
#   32977,
#   32979,
#   32980,
#   212,
#   32984,
#   216,
#   220,
#   32991,
#   32996,
#   33003,
#   33006,
#   241,
#   33012,
#   33013,
#   33026,
#   262,
#   33035,
#   271,
#   33042,
#   292,
#   302,
#   308,
#   33076,
#   33080,
#   321,
#   33098,
#   33110,
#   33111,
#   345,
#   33123,
#   33124,
#   33128,
#   362,
#   366,
#   33149,
#   382,
#   385,
#   33157,
#   390,
#   394,
#   33165,
#   403,
#   406,
#   411,
#   33180,
#   33181,
#   33184,
#   420,
#   33194,
#   33198,
#   33200,
#   433,
# ...

# %%
# actual_images = getActualImages(train_dataset, train_group, 64)
# to get from the first client
first_client_batches = getActualImages(train_dataset, train_group[0], 64)

# %%
for images, labels in first_client_batches:
    print(len(images))
    break
# Out:
# 64
# /Users/icaro.magalhaes/dev/me/mlsec/FLDataset.ipynb:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   "\n",
